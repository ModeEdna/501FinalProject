# %%
# import required libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
from sklearn import preprocessing
# Out:
# /Users/modeedna/opt/anaconda3/envs/ANLY501/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# import data
all = pd.read_csv('../../data/cleanData/allTables.csv')
allNorm = pd.read_csv('../../data/cleanData/allTablesNorm.csv')

# %%
all.head()
# Out:
#    Unnamed: 0  Country Group    Year  Host  PastGroup  DifficultGroup  \
# 0           0  Denmark     A  1/1/02     0          1               1
# 1           1   France     A  1/1/02     0          0               1
# 2           2  Senegal     A  1/1/02     0          1               1
# 3           3  Uruguay     A  1/1/02     0          0               1
# 4           4    Spain     B  1/1/02     0          1               0
#
#    RankFIFA  QualiStreak       Caps  eliteClub        Age
# 0        20            2  24.000000          7  26.212717
# 1         1            2  38.304348         15  27.370376
# 2        42            1  17.826087          0  24.355427
# 3        24            1  22.869565          5  25.345519
# 4         8            7  18.043478          8  25.915279

# %%
allNorm.head()
# Out:
#    Unnamed: 0  Country Group        Year  Host  PastGroup  DifficultGroup  \
# 0           0  Denmark     A  2002-01-01     0          1               1
# 1           1   France     A  2002-01-01     0          0               1
# 2           2  Senegal     A  2002-01-01     0          1               1
# 3           3  Uruguay     A  2002-01-01     0          0               1
# 4           4    Spain     B  2002-01-01     0          1               0
#
#    RankFIFA  QualiStreak      Caps  eliteClub       Age
# 0  0.211111         0.05  0.169307   0.388889  0.497151
# 1  0.000000         0.05  0.495050   0.833333  0.683914
# 2  0.455556         0.00  0.028713   0.000000  0.197517
# 3  0.255556         0.00  0.143564   0.277778  0.357247
# 4  0.077778         0.30  0.033663   0.444444  0.449166

# %%
all.describe()
# Out:
#        Unnamed: 0       Host  PastGroup  DifficultGroup    RankFIFA  \
# count  160.000000  160.00000  160.00000      160.000000  160.000000
# mean    79.500000    0.03750    0.50000        0.250000   23.800000
# std     46.332134    0.19058    0.50157        0.434372   18.446864
# min      0.000000    0.00000    0.00000        0.000000    1.000000
# 25%     39.750000    0.00000    0.00000        0.000000    9.000000
# 50%     79.500000    0.00000    0.50000        0.000000   20.000000
# 75%    119.250000    0.00000    1.00000        0.250000   34.000000
# max    159.000000    1.00000    1.00000        1.000000   91.000000
#
#        QualiStreak        Caps   eliteClub         Age
# count   160.000000  160.000000  160.000000  160.000000
# mean      4.031250   32.725104    4.675000   26.912814
# std       4.424662    8.703270    5.026408    1.138083
# min       1.000000   16.565217    0.000000   23.131107
# 25%       1.000000   26.206522    1.000000   26.098034
# ...

# %%
# heatmap of correlations
sns.heatmap(all.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6, 5), dpi=100)
sns.boxplot(data=all[['RankFIFA','QualiStreak','Caps','eliteClub','Age']], ax=ax)
plt.setp(ax.get_xticklabels(), rotation=90)
ax.set_xlabel("Feature")
ax.set_ylabel("Feature Value (Rank, Streak, Mean, Mean, Mean)");
